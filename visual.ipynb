# %%
% run agents.py
# Out:
# UsageError: Line magic function `%` not found.

# %%
# %run agents.py

# %%
# %run model.py

# %%
# %solara run app.py
# Out:
# UsageError: Line magic function `%solara` not found.

# %%
# Out:
#   Cell In[7], line 1
#     ctx7sk-81d89b61-0c63-4be5-8665-cd4137e94e6a
#             ^
# SyntaxError: invalid decimal literal
